# %% [markdown]
# # Janet Benchmarks Game
#
# Compare Janet to Python and Lua for some of the Computer Language Benchmarks Game
# "artificial" benchmarks.  See all the caveats at: https://benchmarksgame-team.pages.debian.net/benchmarksgame/index.html
#
# See the plot below.
#
# * Janet 1.14.1 (compiled with -fLTO)
# * Python 3.8 (anaconda)
# * Lua 5.4
#
# All benchmark programs in this run are **single threaded**, and run
# on an Intel(R) Core(TM) i5-7500 CPU @ 3.40GHz,
# 4 cores, with hyperthreading disabled.
#
# Pidigits and regexredux are missing Lua implementations for now.
# Partially because I'm not sure what regex library or MP library I
# would use as neither are built in to Lua.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("bench_pylua.csv")
df
# Out:
#                  name   janet  python     lua
# 0            fannkuch    5.04    4.83    1.77
# 1         binarytrees   71.63  110.94  110.01
# 2         knucleotide  137.59  164.44   74.36
# 3               nbody   17.53   37.77   10.48
# 4  reverse-complement   35.78    7.37   34.91
# 5            pidigits    5.98    3.92     NaN
# 6          regexredux   15.86   13.51     NaN

# %%
df.plot.bar(x='name', figsize=(20,10), title="Benchmark Performance",
            xlabel="Benchmark Name", ylabel="Runtime in Seconds (lower is better)")
# Out:
# <AxesSubplot:title={'center':'Benchmark Performance'}, xlabel='Benchmark Name', ylabel='Runtime in Seconds (lower is better)'>
